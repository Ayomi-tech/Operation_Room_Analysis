# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

# %%
raw_df=pd.read_excel('2022_Q1_OR_Utilization.xlsx',index_col=0)

# %%
raw_df.head()
# Out:
#                    Date  OR Suite      Service  CPT Code  \
# Encounter ID
# 10001        2022-01-03         1     Podiatry     28110
# 10002        2022-01-03         1     Podiatry     28055
# 10003        2022-01-03         1     Podiatry     28297
# 10004        2022-01-03         1     Podiatry     28296
# 10005        2022-01-03         2  Orthopedics     27445
#
#                                         CPT Description  Booked Time (min)  \
# Encounter ID
# 10001          Partial ostectomy, fifth metatarsal head                 90
# 10002         Neurectomy, intrinsic musculature of foot                 60
# 10003                              Lapidus bunionectomy                150
# 10004                Bunionectomy with distal osteotomy                120
# 10005               Arthroplasty, knee, hinge prothesis                120
#
#                      OR Schedule           Wheels In          Start Time  \
# Encounter ID
# 10001        2022-01-03 07:00:00 2022-01-03 07:05:00 2022-01-03 07:32:00
# 10002        2022-01-03 08:45:00 2022-01-03 09:48:00 2022-01-03 10:13:00
# 10003        2022-01-03 10:00:00 2022-01-03 11:50:00 2022-01-03 12:20:00
# 10004        2022-01-03 12:45:00 2022-01-03 13:29:00 2022-01-03 13:53:00
# 10005        2022-01-03 07:00:00 2022-01-03 07:15:00 2022-01-03 07:50:00
#
#                         End Time          Wheels Out
# Encounter ID
# 10001        2022-01-03 09:05:00 2022-01-03 09:17:00
# 10002        2022-01-03 11:01:00 2022-01-03 11:12:00
# 10003        2022-01-03 12:42:00 2022-01-03 12:58:00
# 10004        2022-01-03 14:50:00 2022-01-03 15:02:00
# 10005        2022-01-03 09:38:00 2022-01-03 09:51:00

# %%
raw_df.describe()
# Out:
#           OR Suite      CPT Code  Booked Time (min)
# count  2172.000000   2172.000000        2172.000000
# mean      4.288674  44881.405617          77.189227
# std       2.163514  18087.419079          30.430015
# min       1.000000  14060.000000          30.000000
# 25%       3.000000  28296.000000          60.000000
# 50%       4.000000  42826.000000          60.000000
# 75%       6.000000  66982.000000          90.000000
# max       8.000000  69436.000000         180.000000

# %%
# mean time of each services
raw_df.groupby('Service')['Booked Time (min)'].mean().reset_index().sort_values(by='Booked Time (min)', ascending=False).round(decimals=2)
# Out:
#          Service  Booked Time (min)
# 6        Plastic             110.43
# 1        General             110.00
# 2          OBGYN              97.50
# 7       Podiatry              89.51
# 4    Orthopedics              87.38
# 9       Vascular              68.24
# 0            ENT              67.01
# 8        Urology              66.06
# 5     Pediatrics              60.00
# 3  Ophthalmology              44.64

# %%
#adding preparation_time and Actual_time columns 

raw_df['Preperation_time']=(raw_df['Start Time']-raw_df['Wheels In']).astype('timedelta64[m]').astype(int)
raw_df['Actual_time']=(raw_df['Wheels Out']-raw_df['Wheels In']).astype('timedelta64[m]').astype(int)
raw_df.head()
# Out:
#                    Date  OR Suite      Service  CPT Code  \
# Encounter ID
# 10001        2022-01-03         1     Podiatry     28110
# 10002        2022-01-03         1     Podiatry     28055
# 10003        2022-01-03         1     Podiatry     28297
# 10004        2022-01-03         1     Podiatry     28296
# 10005        2022-01-03         2  Orthopedics     27445
#
#                                         CPT Description  Booked Time (min)  \
# Encounter ID
# 10001          Partial ostectomy, fifth metatarsal head                 90
# 10002         Neurectomy, intrinsic musculature of foot                 60
# 10003                              Lapidus bunionectomy                150
# 10004                Bunionectomy with distal osteotomy                120
# 10005               Arthroplasty, knee, hinge prothesis                120
#
#                      OR Schedule           Wheels In          Start Time  \
# Encounter ID
# 10001        2022-01-03 07:00:00 2022-01-03 07:05:00 2022-01-03 07:32:00
# 10002        2022-01-03 08:45:00 2022-01-03 09:48:00 2022-01-03 10:13:00
# 10003        2022-01-03 10:00:00 2022-01-03 11:50:00 2022-01-03 12:20:00
# 10004        2022-01-03 12:45:00 2022-01-03 13:29:00 2022-01-03 13:53:00
# 10005        2022-01-03 07:00:00 2022-01-03 07:15:00 2022-01-03 07:50:00
#
#                         End Time          Wheels Out  Preperation_time  \
# Encounter ID
# 10001        2022-01-03 09:05:00 2022-01-03 09:17:00                27
# 10002        2022-01-03 11:01:00 2022-01-03 11:12:00                25
# 10003        2022-01-03 12:42:00 2022-01-03 12:58:00                30
# 10004        2022-01-03 14:50:00 2022-01-03 15:02:00                24
# 10005        2022-01-03 09:38:00 2022-01-03 09:51:00                35
#
#               Actual_time
# Encounter ID
# 10001                 132
# 10002                  84
# 10003                  68
# 10004                  93
# 10005                 156

# %%
raw_df.sort_values(by=['Date','OR Suite','OR Schedule'])
# Out:
#                    Date  OR Suite      Service  CPT Code  \
# Encounter ID
# 10001        2022-01-03         1     Podiatry     28110
# 10002        2022-01-03         1     Podiatry     28055
# 10003        2022-01-03         1     Podiatry     28297
# 10004        2022-01-03         1     Podiatry     28296
# 10005        2022-01-03         2  Orthopedics     27445
# ...                 ...       ...          ...       ...
# 12168        2022-03-31         7   Pediatrics     69421
# 12169        2022-03-31         7   Pediatrics     69421
# 12170        2022-03-31         8  Orthopedics     27445
# 12171        2022-03-31         8  Orthopedics     27445
# 12172        2022-03-31         8  Orthopedics     27130
#
#                                         CPT Description  Booked Time (min)  \
# Encounter ID
# 10001          Partial ostectomy, fifth metatarsal head                 90
# 10002         Neurectomy, intrinsic musculature of foot                 60
# 10003                              Lapidus bunionectomy                150
# 10004                Bunionectomy with distal osteotomy                120
# 10005               Arthroplasty, knee, hinge prothesis                120
# ...                                                 ...                ...
# 12168                   Myringotomy, general anesthesia                 60
# 12169                   Myringotomy, general anesthesia                 60
# 12170               Arthroplasty, knee, hinge prothesis                120
# 12171               Arthroplasty, knee, hinge prothesis                120
# 12172                                 Arthroplasty, hip                120
#
#                      OR Schedule           Wheels In          Start Time  \
# Encounter ID
# 10001        2022-01-03 07:00:00 2022-01-03 07:05:00 2022-01-03 07:32:00
# 10002        2022-01-03 08:45:00 2022-01-03 09:48:00 2022-01-03 10:13:00
# 10003        2022-01-03 10:00:00 2022-01-03 11:50:00 2022-01-03 12:20:00
# 10004        2022-01-03 12:45:00 2022-01-03 13:29:00 2022-01-03 13:53:00
# 10005        2022-01-03 07:00:00 2022-01-03 07:15:00 2022-01-03 07:50:00
# ...                          ...                 ...                 ...
# 12168        2022-03-31 10:45:00 2022-03-31 11:59:00 2022-03-31 12:11:00
# 12169        2022-03-31 12:00:00 2022-03-31 13:20:00 2022-03-31 13:47:00
# 12170        2022-03-31 07:00:00 2022-03-31 07:06:00 2022-03-31 07:45:00
# 12171        2022-03-31 09:15:00 2022-03-31 09:40:00 2022-03-31 10:15:00
# 12172        2022-03-31 11:30:00 2022-03-31 12:40:00 2022-03-31 13:12:00
#
#                         End Time          Wheels Out  Preperation_time  \
# Encounter ID
# 10001        2022-01-03 09:05:00 2022-01-03 09:17:00                27
# 10002        2022-01-03 11:01:00 2022-01-03 11:12:00                25
# 10003        2022-01-03 12:42:00 2022-01-03 12:58:00                30
# 10004        2022-01-03 14:50:00 2022-01-03 15:02:00                24
# 10005        2022-01-03 09:38:00 2022-01-03 09:51:00                35
# ...                          ...                 ...               ...
# 12168        2022-03-31 12:39:00 2022-03-31 12:51:00                12
# 12169        2022-03-31 14:14:00 2022-03-31 14:28:00                27
# 12170        2022-03-31 09:06:00 2022-03-31 09:18:00                39
# 12171        2022-03-31 11:40:00 2022-03-31 12:01:00                35
# 12172        2022-03-31 14:40:00 2022-03-31 14:58:00                32
#
#               Actual_time
# Encounter ID
# 10001                 132
# 10002                  84
# 10003                  68
# 10004                  93
# 10005                 156
# ...                   ...
# 12168                  52
# 12169                  68
# 12170                 132
# 12171                 141
# 12172                 138
#
# [2172 rows x 13 columns]

# %%
raw_df[(raw_df['OR Schedule']==raw_df['Start Time']) & (raw_df['Start Time'].dt.hour==7)].sort_values(['Date','OR Suite','OR Schedule'])
# Out:
# Empty DataFrame
# Columns: [Date, OR Suite, Service, CPT Code, CPT Description, Booked Time (min), OR Schedule, Wheels In, Start Time, End Time, Wheels Out, Preperation_time, Actual_time]
# Index: []

# %%
# adding a new column case_delay
raw_df['case_delay']=(raw_df['Wheels In']-raw_df['OR Schedule']).astype('timedelta64[m]').astype(int)

# %%
raw_df[(raw_df['OR Schedule'].dt.strftime('%H:%M')=='07:00') & (raw_df['case_delay']<=5)]
# Out:
#                    Date  OR Suite        Service  CPT Code  \
# Encounter ID
# 10001        2022-01-03         1       Podiatry     28110
# 10007        2022-01-03         3  Ophthalmology     66982
# 10015        2022-01-03         4          OBGYN     58562
# 10042        2022-01-04         3  Ophthalmology     66982
# 10050        2022-01-04         4          OBGYN     58562
# ...                 ...       ...            ...       ...
# 12115        2022-03-30         4          OBGYN     58562
# 12144        2022-03-31         3  Ophthalmology     66982
# 12152        2022-03-31         4          OBGYN     58562
# 12156        2022-03-31         5            ENT     42826
# 12161        2022-03-31         6        Plastic     17110
#
#                                        CPT Description  Booked Time (min)  \
# Encounter ID
# 10001         Partial ostectomy, fifth metatarsal head                 90
# 10007                   Extracapsular cataract removal                 45
# 10015                           Hysterectomy, surgical                120
# 10042                   Extracapsular cataract removal                 45
# 10050                           Hysterectomy, surgical                120
# ...                                                ...                ...
# 12115                           Hysterectomy, surgical                120
# 12144                   Extracapsular cataract removal                 45
# 12152                           Hysterectomy, surgical                120
# 12156                                    Tonsillectomy                 60
# 12161                    Removal of benign skin lesion                 60
#
#                      OR Schedule           Wheels In          Start Time  \
# Encounter ID
# 10001        2022-01-03 07:00:00 2022-01-03 07:05:00 2022-01-03 07:32:00
# 10007        2022-01-03 07:00:00 2022-01-03 07:03:00 2022-01-03 07:13:00
# 10015        2022-01-03 07:00:00 2022-01-03 07:03:00 2022-01-03 07:23:00
# 10042        2022-01-04 07:00:00 2022-01-04 07:03:00 2022-01-04 07:13:00
# 10050        2022-01-04 07:00:00 2022-01-04 07:03:00 2022-01-04 07:23:00
# ...                          ...                 ...                 ...
# 12115        2022-03-30 07:00:00 2022-03-30 07:03:00 2022-03-30 07:23:00
# 12144        2022-03-31 07:00:00 2022-03-31 07:03:00 2022-03-31 07:13:00
# 12152        2022-03-31 07:00:00 2022-03-31 07:03:00 2022-03-31 07:23:00
# 12156        2022-03-31 07:00:00 2022-03-31 07:04:00 2022-03-31 07:24:00
# 12161        2022-03-31 07:00:00 2022-03-31 07:04:00 2022-03-31 07:20:00
#
#                         End Time          Wheels Out  Preperation_time  \
# Encounter ID
# 10001        2022-01-03 09:05:00 2022-01-03 09:17:00                27
# 10007        2022-01-03 07:31:00 2022-01-03 07:38:00                10
# 10015        2022-01-03 08:40:00 2022-01-03 08:54:00                20
# 10042        2022-01-04 07:31:00 2022-01-04 07:38:00                10
# 10050        2022-01-04 08:40:00 2022-01-04 08:54:00                20
# ...                          ...                 ...               ...
# 12115        2022-03-30 08:40:00 2022-03-30 08:54:00                20
# 12144        2022-03-31 07:31:00 2022-03-31 07:38:00                10
# 12152        2022-03-31 08:40:00 2022-03-31 08:54:00                20
# 12156        2022-03-31 07:49:00 2022-03-31 08:00:00                20
# 12161        2022-03-31 07:54:00 2022-03-31 08:05:00                16
#
#               Actual_time  case_delay
# Encounter ID
# 10001                 132           5
# 10007                  35           3
# 10015                 111           3
# 10042                  35           3
# 10050                 111           3
# ...                   ...         ...
# 12115                 111           3
# 12144                  35           3
# 12152                 111           3
# 12156                  56           4
# 12161                  61           4
#
# [231 rows x 14 columns]

# %%
b_df=raw_df.groupby('Service')['Booked Time (min)'].mean().reset_index().sort_values(by='Booked Time (min)', ascending=False).round(decimals=2)

# %%
a_df=raw_df.groupby('Service')['Actual_time'].mean().reset_index().sort_values(by='Actual_time', ascending=False).round(decimals=2)

# %%
b_df=b_df.set_index('Service')
a_df=a_df.set_index('Service')

# %%
a_df['Actual_time']-b_df['Booked Time (min)']
# Out:
# Service
# ENT               2.09
# General           3.00
# OBGYN            -5.75
# Ophthalmology    -8.77
# Orthopedics      13.58
# Pediatrics        6.00
# Plastic          -7.01
# Podiatry          4.82
# Urology           4.70
# Vascular         12.94
# dtype: float64

# %% [markdown]
# ### Booked Time vs Actual time spend in or Room accuracy

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

services = b_df.index
y_pos = np.arange(len(services))
performance =(a_df['Actual_time']-b_df['Booked Time (min)']).sort_values(ascending=False)


ax.barh(y_pos, performance, align='center')
ax.set_yticks(y_pos, labels=services)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_ylabel('Services')
ax.set_xlabel('Avg Booking Time VS Actual Time (min)')


plt.show()

# %%
scheduled_hours=(raw_df['OR Schedule'].dt.hour)
scheduled_hours=scheduled_hours.unique()

# %%
raw_df['scheduled_hours']=raw_df['OR Schedule'].dt.hour

# %%
raw_df['scheduled_hours'].unique()
# Out:
# array([ 7,  8, 10, 12,  9, 11, 13, 14, 15])

# %%
dealy_df=(raw_df[['Date','scheduled_hours']].value_counts())

# %%
dealy_df=dealy_df.reset_index().set_index('Date')

# %% [markdown]
# ### Busy Hours By Case

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
hours = dealy_df['scheduled_hours'].unique()
Cases = dealy_df.groupby('scheduled_hours')[0].sum()
ax.bar(hours,Cases)
ax.set_ylabel('No of Cases')
ax.set_xlabel('Time in Hours')
plt.show()

# %%
case_delay_by_5min=raw_df[raw_df['case_delay']<=5]

# %%
case_delay_by_5min.head()
# Out:
#                    Date  OR Suite        Service  CPT Code  \
# Encounter ID
# 10001        2022-01-03         1       Podiatry     28110
# 10007        2022-01-03         3  Ophthalmology     66982
# 10008        2022-01-03         3  Ophthalmology     66982
# 10009        2022-01-03         3  Ophthalmology     66982
# 10010        2022-01-03         3  Ophthalmology     66982
#
#                                        CPT Description  Booked Time (min)  \
# Encounter ID
# 10001         Partial ostectomy, fifth metatarsal head                 90
# 10007                   Extracapsular cataract removal                 45
# 10008                   Extracapsular cataract removal                 45
# 10009                   Extracapsular cataract removal                 45
# 10010                   Extracapsular cataract removal                 45
#
#                      OR Schedule           Wheels In          Start Time  \
# Encounter ID
# 10001        2022-01-03 07:00:00 2022-01-03 07:05:00 2022-01-03 07:32:00
# 10007        2022-01-03 07:00:00 2022-01-03 07:03:00 2022-01-03 07:13:00
# 10008        2022-01-03 08:00:00 2022-01-03 08:00:00 2022-01-03 08:12:00
# 10009        2022-01-03 09:00:00 2022-01-03 09:04:00 2022-01-03 09:15:00
# 10010        2022-01-03 10:00:00 2022-01-03 10:01:00 2022-01-03 10:12:00
#
#                         End Time          Wheels Out  Preperation_time  \
# Encounter ID
# 10001        2022-01-03 09:05:00 2022-01-03 09:17:00                27
# 10007        2022-01-03 07:31:00 2022-01-03 07:38:00                10
# 10008        2022-01-03 08:30:00 2022-01-03 08:41:00                12
# 10009        2022-01-03 09:30:00 2022-01-03 09:39:00                11
# 10010        2022-01-03 10:26:00 2022-01-03 10:34:00                11
#
#               Actual_time  case_delay  scheduled_hours
# Encounter ID
# 10001                 132           5                7
# 10007                  35           3                7
# 10008                  41           0                8
# 10009                  35           4                9
# 10010                  33           1               10
